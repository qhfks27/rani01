# %% [markdown]
# <a href="https://colab.research.google.com/github/qhfks27/rani01/blob/master/PPO_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input, Lambda

import tensorflow as tf

class Actor(object):
    """
        Actor Network for PPO
    """
    def __init__(self, state_dim, action_dim, action_bound, learning_rate, ratio_clipping):

        self.state_dim = state_dim
        self.action_dim = action_dim
        self.action_bound = action_bound
        self.learning_rate = learning_rate
        self.ratio_clipping = ratio_clipping

        self.std_bound = [1e-2, 1.0] # std bound

        self.model = self.build_network()

        self.actor_optimizer = tf.keras.optimizers.Adam(self.learning_rate)

    ## actor network
    def build_network(self):
        state_input = Input((self.state_dim,))
        h1 = Dense(64, activation='relu')(state_input)
        h2 = Dense(32, activation='relu')(h1)
        h3 = Dense(16, activation='relu')(h2)
        out_mu = Dense(self.action_dim, activation='tanh')(h3)
        std_output = Dense(self.action_dim, activation='softplus')(h3)

        # Scale output to [-action_bound, action_bound]
        mu_output = Lambda(lambda x: x*self.action_bound)(out_mu)
        model = Model(state_input, [mu_output, std_output])
        model.summary()
        return model


    ## log policy pdf
    def log_pdf(self, mu, std, action):
        std = tf.clip_by_value(std, self.std_bound[0], self.std_bound[1])
        var = std**2
        log_policy_pdf = -0.5 * (action - mu) ** 2 / var - 0.5 * tf.math.log(var * 2 * np.pi)
        return tf.reduce_sum(log_policy_pdf, 1, keepdims=True)


    ## actor policy
    def get_policy_action(self, state):
        # type of action in env is numpy array
        # np.reshape(state, [1, self.state_dim]) : shape (state_dim,) -> shape (1, state_dim)
        # why [0]?  shape (1, action_dim) -> (action_dim,)
        mu_a, std_a = self.model.predict(np.reshape(state, [1, self.state_dim]))
        mu_a = mu_a[0]
        std_a = std_a[0]
        std_a = np.clip(std_a, self.std_bound[0], self.std_bound[1])
        action = np.random.normal(mu_a, std_a, size=self.action_dim)
        return mu_a, std_a, action

    ## actor prediction
    def predict(self, state):
        mu_a, _= self.model.predict(np.reshape(state, [1, self.state_dim]))
        return mu_a[0]


    ## train the actor network
    def train(self, log_old_policy_pdf, states, actions, advantages):
        with tf.GradientTape() as tape:
            # current policy pdf
            mu_a, std_a = self.model(states)
            log_policy_pdf = self.log_pdf(mu_a, std_a, actions)

            # ratio of current and old policies
            ratio = tf.exp(log_policy_pdf - log_old_policy_pdf)
            clipped_ratio = tf.clip_by_value(ratio, 1.0-self.ratio_clipping, 1.0+self.ratio_clipping)
            surrogate = -tf.minimum(ratio * advantages, clipped_ratio * advantages)
            loss = tf.reduce_mean(surrogate)
        dj_dtheta = tape.gradient(loss, self.model.trainable_variables)
        grads = zip(dj_dtheta, self.model.trainable_variables)
        self.actor_optimizer.apply_gradients(grads)

    ## save actor weights
    def save_weights(self, path):
        self.model.save_weights(path)


    ## load actor wieghts
    def load_weights(self, path):
        self.model.load_weights(path + 'pendulum_actor.h5')

# %%
# PPO with GAE Critic

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.optimizers import Adam

class Critic(object):
    """
        Critic Network for PPO: V function approximator
    """
    def __init__(self, state_dim, action_dim, learning_rate):

        self.state_dim = state_dim
        self.action_dim = action_dim
        self.learning_rate = learning_rate

        # create and compile critic network
        self.model, self.states = self.build_network()

        self.model.compile(optimizer=Adam(self.learning_rate), loss='mse')

    ## critic network
    def build_network(self):
        state_input = Input((self.state_dim,))
        h1 = Dense(64, activation='relu')(state_input)
        h2 = Dense(32, activation='relu')(h1)
        h3 = Dense(16, activation='relu')(h2)
        v_output = Dense(1, activation='linear')(h3)
        model = Model(state_input, v_output)
        model.summary()
        return model, state_input


    ## single gradient update on a single batch data
    def train_on_batch(self, states, td_targets):
        return self.model.train_on_batch(states, td_targets)


    ## save critic weights
    def save_weights(self, path):
        self.model.save_weights(path)


    ## load critic wieghts
    def load_weights(self, path):
        self.model.load_weights(path + 'pendulum_critic.h5')

# %%
# PPO with GAE Agent for training and evaluation

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt


class PPOagent(object):

    def __init__(self, env):

        # hyperparameters
        self.GAMMA = 0.95
        self.GAE_LAMBDA = 0.9 #0.8
        self.BATCH_SIZE = 64
        self.ACTOR_LEARNING_RATE = 0.0001
        self.CRITIC_LEARNING_RATE = 0.001
        self.RATIO_CLIPPING = 0.2
        self.EPOCHS = 10

        self.env = env
        # get state dimension
        self.state_dim = env.observation_space.shape[0]
        # get action dimension
        self.action_dim = env.action_space.shape[0]
        # get action bound
        self.action_bound = env.action_space.high[0]

        # create actor and critic networks
        self.actor = Actor(self.state_dim, self.action_dim, self.action_bound,
                           self.ACTOR_LEARNING_RATE, self.RATIO_CLIPPING)
        self.critic = Critic(self.state_dim, self.action_dim, self.CRITIC_LEARNING_RATE)

        # save the results
        self.save_epi_reward = []


    ## computing Advantages and targets: y_k = r_k + gamma*V(s_k+1), A(s_k, a_k)= y_k - V(s_k)
    def gae_target(self, rewards, v_values, next_v_value, done):
        n_step_targets = np.zeros_like(rewards)
        gae = np.zeros_like(rewards)
        gae_cumulative = 0
        forward_val = 0

        if not done:
            forward_val = next_v_value

        for k in reversed(range(0, len(rewards))):
            delta = rewards[k] + self.GAMMA * forward_val - v_values[k]
            gae_cumulative = self.GAMMA * self.GAE_LAMBDA * gae_cumulative + delta
            gae[k] = gae_cumulative
            forward_val = v_values[k]
            n_step_targets[k] = gae[k] + v_values[k]
        return gae, n_step_targets


    ## convert (list of np.array) to np.array
    def unpack_batch(self, batch):
        unpack = batch[0]
        for idx in range(len(batch)-1):
            unpack = np.append(unpack, batch[idx+1], axis=0)

        return unpack


    ## train the agent
    def train(self, max_episode_num):

        # initialize batch
        batch_state, batch_action, batch_reward = [], [], []
        batch_log_old_policy_pdf = []

        for ep in range(int(max_episode_num)):

            # reset episode
            time, episode_reward, done = 0, 0, False
            # reset the environment and observe the first state
            state = self.env.reset() # shape of state from gym (3,)

            while not done:

                # visualize the environment
                #self.env.render()
                # compute mu and std of old policy and pick an action (shape of gym action = (action_dim,) )
                mu_old, std_old, action = self.actor.get_policy_action(state)
                # clip continuous action to be within action_bound
                action = np.clip(action, -self.action_bound, self.action_bound)
                # compute log old policy pdf
                var_old = std_old ** 2
                log_old_policy_pdf = -0.5 * (action - mu_old) ** 2 / var_old - 0.5 * np.log(var_old * 2 * np.pi)
                log_old_policy_pdf = np.sum(log_old_policy_pdf)
                # observe reward, new_state, shape of output of gym (state_dim,)
                next_state, reward, done, _ = self.env.step(action)
                # change shape (state_dim,) -> (1, state_dim), same to mu, std, action
                state = np.reshape(state, [1, self.state_dim])
                action = np.reshape(action, [1, self.action_dim])
                reward = np.reshape(reward, [1, 1])
                log_old_policy_pdf = np.reshape(log_old_policy_pdf, [1, 1])

                # append to the batch
                batch_state.append(state)
                batch_action.append(action)
                batch_reward.append((reward+8)/8) # <-- normalization
                #batch_reward.append(reward)
                batch_log_old_policy_pdf.append(log_old_policy_pdf)

                # continue until batch becomes full
                if len(batch_state) < self.BATCH_SIZE:
                    # update current state
                    state = next_state
                    episode_reward += reward[0]
                    time += 1
                    continue

                # extract batched states, actions, td_targets, advantages
                states = self.unpack_batch(batch_state)
                actions = self.unpack_batch(batch_action)
                rewards = self.unpack_batch(batch_reward)
                log_old_policy_pdfs = self.unpack_batch(batch_log_old_policy_pdf)

                # clear the batch
                batch_state, batch_action, batch_reward = [], [], []
                batch_log_old_policy_pdf = []

                # compute gae and TD targets
                next_state = np.reshape(next_state, [1, self.state_dim])
                next_v_value = self.critic.model.predict(next_state)
                v_values = self.critic.model.predict(states)
                gaes, y_i = self.gae_target(rewards, v_values, next_v_value, done)

                # update the networks
                for _ in range(self.EPOCHS):

                    # train
                    self.actor.train(log_old_policy_pdfs, states, actions, gaes)
                    self.critic.train_on_batch(states, y_i)

                # update current state
                state = next_state
                episode_reward += reward[0]
                time += 1

            ## display rewards every episode
            print('Episode: ', ep+1, 'Time: ', time, 'Reward: ', episode_reward)

            self.save_epi_reward.append(episode_reward)


            ## save weights every episode
            if ep % 10 == 0:
                self.actor.save_weights("./save_weights/pendulum_actor.h5")
                self.critic.save_weights("./save_weights/pendulum_critic.h5")

        np.savetxt('./save_weights/pendulum_epi_reward.txt', self.save_epi_reward)
        print(self.save_epi_reward)


    ## save them to file if done
    def plot_result(self):
        plt.plot(self.save_epi_reward)
        plt.show()

# %%
import gym

def main():

    max_episode_num = 1000
    env_name = 'Pendulum-v0'
    env = gym.make(env_name)
    agent = PPOagent(env)

    agent.train(max_episode_num)

    agent.plot_result()



if __name__=="__main__":
    main()
# Out:
# Model: "functional_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 3)]          0
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 64)           256         input_3[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 32)           2080        dense_9[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 16)           528         dense_10[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 1)            17          dense_11[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 1)            0           dense_12[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 1)            17          dense_11[0][0]
# ==================================================================================================
# Total params: 2,898
# Trainable params: 2,898
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "functional_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 3)]               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 64)                256
# _________________________________________________________________
# dense_15 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_16 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 2,881
# Trainable params: 2,881
# Non-trainable params: 0
# _________________________________________________________________
# Episode:  1 Time:  200 Reward:  [-1105.19553534]
# Episode:  2 Time:  200 Reward:  [-1478.67205813]
# Episode:  3 Time:  200 Reward:  [-1402.12053345]
# Episode:  4 Time:  200 Reward:  [-1432.48778382]
# Episode:  5 Time:  200 Reward:  [-1226.49693289]
# Episode:  6 Time:  200 Reward:  [-1365.9942007]
# Episode:  7 Time:  200 Reward:  [-1411.9700343]
# Episode:  8 Time:  200 Reward:  [-1456.35231477]
# Episode:  9 Time:  200 Reward:  [-891.57606468]
# Episode:  10 Time:  200 Reward:  [-1327.97376199]
# Episode:  11 Time:  200 Reward:  [-1202.33904918]
# Episode:  12 Time:  200 Reward:  [-1316.60416265]
# Episode:  13 Time:  200 Reward:  [-1098.67032946]
# Episode:  14 Time:  200 Reward:  [-1348.05087843]
# Episode:  15 Time:  200 Reward:  [-1319.5373004]
# Episode:  16 Time:  200 Reward:  [-1109.67936223]
# Episode:  17 Time:  200 Reward:  [-973.90665746]
# Episode:  18 Time:  200 Reward:  [-1347.33037703]
# Episode:  19 Time:  200 Reward:  [-1087.58476281]
# Episode:  20 Time:  200 Reward:  [-896.13764825]
# Episode:  21 Time:  200 Reward:  [-1321.64719757]
# Episode:  22 Time:  200 Reward:  [-1016.92357661]
# Episode:  23 Time:  200 Reward:  [-1231.73925599]
# Episode:  24 Time:  200 Reward:  [-1028.75837106]
# Episode:  25 Time:  200 Reward:  [-980.50813656]
# Episode:  26 Time:  200 Reward:  [-1125.86592503]
# Episode:  27 Time:  200 Reward:  [-1028.80123167]
# Episode:  28 Time:  200 Reward:  [-1089.92829072]
# Episode:  29 Time:  200 Reward:  [-1146.6137358]
# Episode:  30 Time:  200 Reward:  [-879.34642834]
# Episode:  31 Time:  200 Reward:  [-1321.76275965]
# Episode:  32 Time:  200 Reward:  [-865.38455692]
# Episode:  33 Time:  200 Reward:  [-1402.7735654]
# Episode:  34 Time:  200 Reward:  [-1201.21848259]
# Episode:  35 Time:  200 Reward:  [-1080.28415142]
# Episode:  36 Time:  200 Reward:  [-967.29496509]
# Episode:  37 Time:  200 Reward:  [-747.56293841]
# Episode:  38 Time:  200 Reward:  [-958.83409937]
# Episode:  39 Time:  200 Reward:  [-1171.34361211]
# Episode:  40 Time:  200 Reward:  [-1075.77152743]
# Episode:  41 Time:  200 Reward:  [-718.56781259]
# Episode:  42 Time:  200 Reward:  [-850.88299509]
# Episode:  43 Time:  200 Reward:  [-1105.55561506]
# Episode:  44 Time:  200 Reward:  [-1207.08269822]
# Episode:  45 Time:  200 Reward:  [-1004.51127431]
# Episode:  46 Time:  200 Reward:  [-982.49081374]
# Episode:  47 Time:  200 Reward:  [-1194.66954347]
# Episode:  48 Time:  200 Reward:  [-1132.74097518]
# Episode:  49 Time:  200 Reward:  [-1073.93668907]
# Episode:  50 Time:  200 Reward:  [-759.46371848]
# Episode:  51 Time:  200 Reward:  [-855.78497877]
# Episode:  52 Time:  200 Reward:  [-856.27002352]
# Episode:  53 Time:  200 Reward:  [-762.31252674]
# Episode:  54 Time:  200 Reward:  [-978.27260146]
# Episode:  55 Time:  200 Reward:  [-1223.15031633]
# Episode:  56 Time:  200 Reward:  [-1141.36689138]
# Episode:  57 Time:  200 Reward:  [-1001.88056987]
# Episode:  58 Time:  200 Reward:  [-1035.99739768]
# Episode:  59 Time:  200 Reward:  [-753.34143894]
# Episode:  60 Time:  200 Reward:  [-891.41291601]
# Episode:  61 Time:  200 Reward:  [-852.4511074]
# Episode:  62 Time:  200 Reward:  [-872.18853071]
# Episode:  63 Time:  200 Reward:  [-811.32693413]
# Episode:  64 Time:  200 Reward:  [-847.30082345]
# Episode:  65 Time:  200 Reward:  [-864.96566486]
# Episode:  66 Time:  200 Reward:  [-851.60534835]
# Episode:  67 Time:  200 Reward:  [-814.80290044]
# Episode:  68 Time:  200 Reward:  [-981.57317039]
# Episode:  69 Time:  200 Reward:  [-860.96860955]
# Episode:  70 Time:  200 Reward:  [-860.9429464]
# Episode:  71 Time:  200 Reward:  [-752.86854391]
# Episode:  72 Time:  200 Reward:  [-1216.43070189]
# Episode:  73 Time:  200 Reward:  [-1181.62165578]
# Episode:  74 Time:  200 Reward:  [-879.87940445]
# Episode:  75 Time:  200 Reward:  [-971.8126022]
# Episode:  76 Time:  200 Reward:  [-1072.23619519]
# Episode:  77 Time:  200 Reward:  [-962.27950029]
# Episode:  78 Time:  200 Reward:  [-966.98969554]
# Episode:  79 Time:  200 Reward:  [-983.81069611]
# Episode:  80 Time:  200 Reward:  [-874.53680022]
# Episode:  81 Time:  200 Reward:  [-1243.95788199]
# Episode:  82 Time:  200 Reward:  [-1013.69014572]
# Episode:  83 Time:  200 Reward:  [-841.67589389]
# Episode:  84 Time:  200 Reward:  [-994.20077209]
# Episode:  85 Time:  200 Reward:  [-888.76864148]
# Episode:  86 Time:  200 Reward:  [-1107.674939]
# Episode:  87 Time:  200 Reward:  [-868.2087219]
# Episode:  88 Time:  200 Reward:  [-958.05898608]
# Episode:  89 Time:  200 Reward:  [-964.26733611]
# Episode:  90 Time:  200 Reward:  [-974.19874115]
# Episode:  91 Time:  200 Reward:  [-1145.03325306]
# Episode:  92 Time:  200 Reward:  [-742.71536284]
# Episode:  93 Time:  200 Reward:  [-1079.66338448]
# Episode:  94 Time:  200 Reward:  [-990.07580845]
# Episode:  95 Time:  200 Reward:  [-867.49533879]
# Episode:  96 Time:  200 Reward:  [-1011.20148286]
# Episode:  97 Time:  200 Reward:  [-771.96738647]
# Episode:  98 Time:  200 Reward:  [-970.07285905]
# Episode:  99 Time:  200 Reward:  [-877.67548388]
# Episode:  100 Time:  200 Reward:  [-1003.03182594]
# Episode:  101 Time:  200 Reward:  [-991.07096706]
# Episode:  102 Time:  200 Reward:  [-1078.08307348]
# Episode:  103 Time:  200 Reward:  [-1112.79455822]
# Episode:  104 Time:  200 Reward:  [-757.88180254]
# Episode:  105 Time:  200 Reward:  [-1040.06150611]
# Episode:  106 Time:  200 Reward:  [-738.86852426]
# Episode:  107 Time:  200 Reward:  [-995.58765173]
# Episode:  108 Time:  200 Reward:  [-703.95041575]
# Episode:  109 Time:  200 Reward:  [-759.07672751]
# Episode:  110 Time:  200 Reward:  [-896.81069186]
# Episode:  111 Time:  200 Reward:  [-967.42953706]
# Episode:  112 Time:  200 Reward:  [-1152.82215973]
# Episode:  113 Time:  200 Reward:  [-633.40968779]
# Episode:  114 Time:  200 Reward:  [-884.71753463]
# Episode:  115 Time:  200 Reward:  [-866.06734823]
# Episode:  116 Time:  200 Reward:  [-642.81640079]
# Episode:  117 Time:  200 Reward:  [-975.83464769]
# Episode:  118 Time:  200 Reward:  [-787.52888696]
# Episode:  119 Time:  200 Reward:  [-749.5708085]
# Episode:  120 Time:  200 Reward:  [-963.36488256]
# Episode:  121 Time:  200 Reward:  [-841.54037871]
# Episode:  122 Time:  200 Reward:  [-741.8931351]
# Episode:  123 Time:  200 Reward:  [-758.58768661]
# Episode:  124 Time:  200 Reward:  [-1087.78820861]
# Episode:  125 Time:  200 Reward:  [-1042.92533221]
# Episode:  126 Time:  200 Reward:  [-728.24786388]
# Episode:  127 Time:  200 Reward:  [-1245.92393339]
# Episode:  128 Time:  200 Reward:  [-780.35704545]
# Episode:  129 Time:  200 Reward:  [-1102.9433219]
# Episode:  130 Time:  200 Reward:  [-1131.18105191]
# Episode:  131 Time:  200 Reward:  [-633.92281327]
# Episode:  132 Time:  200 Reward:  [-1048.917749]
# Episode:  133 Time:  200 Reward:  [-778.51334994]
# Episode:  134 Time:  200 Reward:  [-1102.00774419]
# Episode:  135 Time:  200 Reward:  [-1083.39047767]
# Episode:  136 Time:  200 Reward:  [-1150.83266245]
# Episode:  137 Time:  200 Reward:  [-1019.61922983]
# Episode:  138 Time:  200 Reward:  [-759.26643671]
# Episode:  139 Time:  200 Reward:  [-765.99156165]
# Episode:  140 Time:  200 Reward:  [-885.92391628]
# Episode:  141 Time:  200 Reward:  [-860.4093947]
# Episode:  142 Time:  200 Reward:  [-642.75913771]
# Episode:  143 Time:  200 Reward:  [-870.55170588]
# Episode:  144 Time:  200 Reward:  [-850.46286128]
# Episode:  145 Time:  200 Reward:  [-995.59745636]
# Episode:  146 Time:  200 Reward:  [-867.68644247]
# Episode:  147 Time:  200 Reward:  [-622.91828329]
# Episode:  148 Time:  200 Reward:  [-777.98400226]
# Episode:  149 Time:  200 Reward:  [-643.19587736]
# Episode:  150 Time:  200 Reward:  [-986.49308838]
# Episode:  151 Time:  200 Reward:  [-789.46041667]
# Episode:  152 Time:  200 Reward:  [-505.28906323]
# Episode:  153 Time:  200 Reward:  [-771.08376844]
# Episode:  154 Time:  200 Reward:  [-504.50277847]
# Episode:  155 Time:  200 Reward:  [-873.75616517]
# Episode:  156 Time:  200 Reward:  [-890.58699438]
# Episode:  157 Time:  200 Reward:  [-847.6645115]
# Episode:  158 Time:  200 Reward:  [-505.2926398]
# Episode:  159 Time:  200 Reward:  [-753.72265755]
# Episode:  160 Time:  200 Reward:  [-631.47609172]
# Episode:  161 Time:  200 Reward:  [-737.70489504]
# Episode:  162 Time:  200 Reward:  [-502.07022296]
# Episode:  163 Time:  200 Reward:  [-851.11782438]
# Episode:  164 Time:  200 Reward:  [-758.69255888]
# Episode:  165 Time:  200 Reward:  [-643.0609376]
# Episode:  166 Time:  200 Reward:  [-628.62655471]
# Episode:  167 Time:  200 Reward:  [-543.94656007]
# Episode:  168 Time:  200 Reward:  [-511.40139898]
# Episode:  169 Time:  200 Reward:  [-898.34633551]
# Episode:  170 Time:  200 Reward:  [-881.75004761]
# Episode:  171 Time:  200 Reward:  [-824.89095368]
# Episode:  172 Time:  200 Reward:  [-757.89737351]
# Episode:  173 Time:  200 Reward:  [-728.26446202]
# Episode:  174 Time:  200 Reward:  [-838.84582533]
# Episode:  175 Time:  200 Reward:  [-628.17502947]
# Episode:  176 Time:  200 Reward:  [-777.86325846]
# Episode:  177 Time:  200 Reward:  [-735.06370067]
# Episode:  178 Time:  200 Reward:  [-861.56174082]
# Episode:  179 Time:  200 Reward:  [-802.02667384]
# Episode:  180 Time:  200 Reward:  [-627.47388234]
# Episode:  181 Time:  200 Reward:  [-851.64939205]
# Episode:  182 Time:  200 Reward:  [-929.23270315]
# Episode:  183 Time:  200 Reward:  [-955.85430928]
# Episode:  184 Time:  200 Reward:  [-503.60804658]
# Episode:  185 Time:  200 Reward:  [-750.90663774]
# Episode:  186 Time:  200 Reward:  [-390.09786397]
# Episode:  187 Time:  200 Reward:  [-524.99137294]
# Episode:  188 Time:  200 Reward:  [-745.98242976]
# Episode:  189 Time:  200 Reward:  [-617.78149956]
# Episode:  190 Time:  200 Reward:  [-502.65762588]
# Episode:  191 Time:  200 Reward:  [-763.57036352]
# Episode:  192 Time:  200 Reward:  [-1021.97073032]
# Episode:  193 Time:  200 Reward:  [-902.93171969]
# Episode:  194 Time:  200 Reward:  [-618.80048082]
# Episode:  195 Time:  200 Reward:  [-744.61395135]
# Episode:  196 Time:  200 Reward:  [-854.0208633]
# Episode:  197 Time:  200 Reward:  [-751.19556648]
# Episode:  198 Time:  200 Reward:  [-875.05464824]
# Episode:  199 Time:  200 Reward:  [-986.1237062]
# Episode:  200 Time:  200 Reward:  [-1001.25139401]
# Episode:  201 Time:  200 Reward:  [-990.09588411]
# Episode:  202 Time:  200 Reward:  [-885.86823627]
# Episode:  203 Time:  200 Reward:  [-766.76236678]
# Episode:  204 Time:  200 Reward:  [-758.3348737]
# Episode:  205 Time:  200 Reward:  [-1087.14058658]
# Episode:  206 Time:  200 Reward:  [-1064.66719336]
# Episode:  207 Time:  200 Reward:  [-1089.10414788]
# Episode:  208 Time:  200 Reward:  [-1124.18455612]
# Episode:  209 Time:  200 Reward:  [-1187.15289883]
# Episode:  210 Time:  200 Reward:  [-483.12530124]
# Episode:  211 Time:  200 Reward:  [-378.92840143]
# Episode:  212 Time:  200 Reward:  [-914.92687209]
# Episode:  213 Time:  200 Reward:  [-757.64291459]
# Episode:  214 Time:  200 Reward:  [-386.77393847]
# Episode:  215 Time:  200 Reward:  [-774.02703692]
# Episode:  216 Time:  200 Reward:  [-503.86134729]
# Episode:  217 Time:  200 Reward:  [-1029.69374098]
# Episode:  218 Time:  200 Reward:  [-804.34968239]
# Episode:  219 Time:  200 Reward:  [-904.58283066]
# Episode:  220 Time:  200 Reward:  [-752.56880453]
# Episode:  221 Time:  200 Reward:  [-1154.50178236]
# Episode:  222 Time:  200 Reward:  [-1137.85780801]
# Episode:  223 Time:  200 Reward:  [-657.40797179]
# Episode:  224 Time:  200 Reward:  [-304.5817621]
# Episode:  225 Time:  200 Reward:  [-641.49330139]
# Episode:  226 Time:  200 Reward:  [-124.97503523]
# Episode:  227 Time:  200 Reward:  [-785.53139854]
# Episode:  228 Time:  200 Reward:  [-389.75445163]
# Episode:  229 Time:  200 Reward:  [-889.74706903]
# Episode:  230 Time:  200 Reward:  [-138.46238125]
# Episode:  231 Time:  200 Reward:  [-666.29562288]
# Episode:  232 Time:  200 Reward:  [-636.60622564]
# Episode:  233 Time:  200 Reward:  [-523.83127853]
# Episode:  234 Time:  200 Reward:  [-390.76581724]
# Episode:  235 Time:  200 Reward:  [-883.97962629]
# Episode:  236 Time:  200 Reward:  [-756.18317702]
# Episode:  237 Time:  200 Reward:  [-504.04814927]
# Episode:  238 Time:  200 Reward:  [-625.38785828]
# Episode:  239 Time:  200 Reward:  [-130.90874523]
# Episode:  240 Time:  200 Reward:  [-3.15184107]
# Episode:  241 Time:  200 Reward:  [-768.67147725]
# Episode:  242 Time:  200 Reward:  [-498.82618886]
# Episode:  243 Time:  200 Reward:  [-128.32579286]
# Episode:  244 Time:  200 Reward:  [-550.10679965]
# Episode:  245 Time:  200 Reward:  [-418.50060492]
# Episode:  246 Time:  200 Reward:  [-525.92855224]
# Episode:  247 Time:  200 Reward:  [-1034.04998542]
# Episode:  248 Time:  200 Reward:  [-830.70125499]
# Episode:  249 Time:  200 Reward:  [-1022.05607948]
# Episode:  250 Time:  200 Reward:  [-1062.76940652]
# Episode:  251 Time:  200 Reward:  [-255.28959923]
# Episode:  252 Time:  200 Reward:  [-1168.56801985]
# Episode:  253 Time:  200 Reward:  [-949.75584423]
# Episode:  254 Time:  200 Reward:  [-862.78724296]
# Episode:  255 Time:  200 Reward:  [-771.89739995]
# Episode:  256 Time:  200 Reward:  [-136.35178508]
# Episode:  257 Time:  200 Reward:  [-4.86892887]
# Episode:  258 Time:  200 Reward:  [-1223.55039447]
# Episode:  259 Time:  200 Reward:  [-1053.92245956]
# Episode:  260 Time:  200 Reward:  [-1218.80934945]
# Episode:  261 Time:  200 Reward:  [-1056.36617333]
# Episode:  262 Time:  200 Reward:  [-129.61132716]
# Episode:  263 Time:  200 Reward:  [-248.60664496]
# Episode:  264 Time:  200 Reward:  [-370.65605371]
# Episode:  265 Time:  200 Reward:  [-255.58259362]
# Episode:  266 Time:  200 Reward:  [-657.43406564]
# Episode:  267 Time:  200 Reward:  [-127.84790182]
# Episode:  268 Time:  200 Reward:  [-392.75500548]
# Episode:  269 Time:  200 Reward:  [-375.7555827]
# Episode:  270 Time:  200 Reward:  [-126.18344389]
# Episode:  271 Time:  200 Reward:  [-128.38956015]
# Episode:  272 Time:  200 Reward:  [-656.89517664]
# Episode:  273 Time:  200 Reward:  [-124.54831075]
# Episode:  274 Time:  200 Reward:  [-258.35229901]
# Episode:  275 Time:  200 Reward:  [-261.26243014]
# Episode:  276 Time:  200 Reward:  [-258.66580851]
# Episode:  277 Time:  200 Reward:  [-255.1023755]
# Episode:  278 Time:  200 Reward:  [-857.45982937]
# Episode:  279 Time:  200 Reward:  [-644.0461276]
# Episode:  280 Time:  200 Reward:  [-516.7500542]
# Episode:  281 Time:  200 Reward:  [-515.68998514]
# Episode:  282 Time:  200 Reward:  [-756.4548729]
# Episode:  283 Time:  200 Reward:  [-648.38202081]
# Episode:  284 Time:  200 Reward:  [-1013.55804001]
# Episode:  285 Time:  200 Reward:  [-497.70081415]
# Episode:  286 Time:  200 Reward:  [-630.23462615]
# Episode:  287 Time:  200 Reward:  [-376.24924946]
# Episode:  288 Time:  200 Reward:  [-375.21510189]
# Episode:  289 Time:  200 Reward:  [-378.30387575]
# Episode:  290 Time:  200 Reward:  [-384.91588566]
# Episode:  291 Time:  200 Reward:  [-128.84964847]
# Episode:  292 Time:  200 Reward:  [-381.9244631]
# Episode:  293 Time:  200 Reward:  [-381.52164233]
# Episode:  294 Time:  200 Reward:  [-858.11535193]
# Episode:  295 Time:  200 Reward:  [-1081.33638542]
# Episode:  296 Time:  200 Reward:  [-561.79403323]
# Episode:  297 Time:  200 Reward:  [-256.76241782]
# Episode:  298 Time:  200 Reward:  [-130.412052]
# Episode:  299 Time:  200 Reward:  [-253.47137178]
# Episode:  300 Time:  200 Reward:  [-126.8504967]
# Episode:  301 Time:  200 Reward:  [-528.18991165]
# Episode:  302 Time:  200 Reward:  [-390.16282258]
# Episode:  303 Time:  200 Reward:  [-506.75673825]
# Episode:  304 Time:  200 Reward:  [-251.49739295]
# Episode:  305 Time:  200 Reward:  [-906.57939888]
# Episode:  306 Time:  200 Reward:  [-131.46449951]
# Episode:  307 Time:  200 Reward:  [-900.50629264]
# Episode:  308 Time:  200 Reward:  [-250.02660657]
# Episode:  309 Time:  200 Reward:  [-1052.56832623]
# Episode:  310 Time:  200 Reward:  [-946.80510058]
# Episode:  311 Time:  200 Reward:  [-828.96712748]
# Episode:  312 Time:  200 Reward:  [-906.60131085]
# Episode:  313 Time:  200 Reward:  [-129.81102281]
# Episode:  314 Time:  200 Reward:  [-251.39823123]
# Episode:  315 Time:  200 Reward:  [-123.72562192]
# Episode:  316 Time:  200 Reward:  [-246.53136582]
# Episode:  317 Time:  200 Reward:  [-132.07095755]
# Episode:  318 Time:  200 Reward:  [-130.09107745]
# Episode:  319 Time:  200 Reward:  [-253.31254676]
# Episode:  320 Time:  200 Reward:  [-6.13077719]
# Episode:  321 Time:  200 Reward:  [-941.06415863]
# Episode:  322 Time:  200 Reward:  [-662.5614165]
# Episode:  323 Time:  200 Reward:  [-130.82576089]
# Episode:  324 Time:  200 Reward:  [-380.10207978]
# Episode:  325 Time:  200 Reward:  [-0.36017545]
# Episode:  326 Time:  200 Reward:  [-386.09415928]
# Episode:  327 Time:  200 Reward:  [-586.26761624]
# Episode:  328 Time:  200 Reward:  [-685.43821634]
# Episode:  329 Time:  200 Reward:  [-423.72930676]
# Episode:  330 Time:  200 Reward:  [-520.76465079]
# Episode:  331 Time:  200 Reward:  [-777.16670154]
# Episode:  332 Time:  200 Reward:  [-494.089984]
# Episode:  333 Time:  200 Reward:  [-505.77741483]
# Episode:  334 Time:  200 Reward:  [-518.06898322]
# Episode:  335 Time:  200 Reward:  [-135.03356346]
# Episode:  336 Time:  200 Reward:  [-841.79665793]
# Episode:  337 Time:  200 Reward:  [-624.46050341]
# Episode:  338 Time:  200 Reward:  [-134.83591031]
# Episode:  339 Time:  200 Reward:  [-639.56624127]
# Episode:  340 Time:  200 Reward:  [-387.22862587]
# Episode:  341 Time:  200 Reward:  [-498.40155948]
# Episode:  342 Time:  200 Reward:  [-388.62196715]
# Episode:  343 Time:  200 Reward:  [-644.71106934]
# Episode:  344 Time:  200 Reward:  [-387.80328393]
# Episode:  345 Time:  200 Reward:  [-605.61432338]
# Episode:  346 Time:  200 Reward:  [-126.97467902]
# Episode:  347 Time:  200 Reward:  [-495.3818209]
# Episode:  348 Time:  200 Reward:  [-0.64528612]
# Episode:  349 Time:  200 Reward:  [-764.84134136]
# Episode:  350 Time:  200 Reward:  [-130.23038975]
# Episode:  351 Time:  200 Reward:  [-707.83018624]
# Episode:  352 Time:  200 Reward:  [-378.95886335]
# Episode:  353 Time:  200 Reward:  [-128.36324475]
# Episode:  354 Time:  200 Reward:  [-131.0004346]
# Episode:  355 Time:  200 Reward:  [-490.41637935]
# Episode:  356 Time:  200 Reward:  [-0.80929412]
# Episode:  357 Time:  200 Reward:  [-968.79337575]
# Episode:  358 Time:  200 Reward:  [-965.53326853]
# Episode:  359 Time:  200 Reward:  [-1006.54976387]
# Episode:  360 Time:  200 Reward:  [-922.38912091]
# Episode:  361 Time:  200 Reward:  [-0.2418238]
# Episode:  362 Time:  200 Reward:  [-264.577996]
# Episode:  363 Time:  200 Reward:  [-249.23251539]
# Episode:  364 Time:  200 Reward:  [-915.00169712]
# Episode:  365 Time:  200 Reward:  [-1003.21918283]
# Episode:  366 Time:  200 Reward:  [-128.90744423]
# Episode:  367 Time:  200 Reward:  [-521.24896917]
# Episode:  368 Time:  200 Reward:  [-129.05589336]
# Episode:  369 Time:  200 Reward:  [-266.16435135]
# Episode:  370 Time:  200 Reward:  [-1017.0700272]
# Episode:  371 Time:  200 Reward:  [-891.5534072]
# Episode:  372 Time:  200 Reward:  [-907.33151182]
# Episode:  373 Time:  200 Reward:  [-393.81857128]
# Episode:  374 Time:  200 Reward:  [-504.63987415]
# Episode:  375 Time:  200 Reward:  [-133.86805735]
# Episode:  376 Time:  200 Reward:  [-4.26700632]
# Episode:  377 Time:  200 Reward:  [-393.40812891]
# Episode:  378 Time:  200 Reward:  [-1077.92003558]
# Episode:  379 Time:  200 Reward:  [-132.36563331]
# Episode:  380 Time:  200 Reward:  [-123.80943373]
# Episode:  381 Time:  200 Reward:  [-367.97770255]
# Episode:  382 Time:  200 Reward:  [-129.53446802]
# Episode:  383 Time:  200 Reward:  [-1144.30646699]
# Episode:  384 Time:  200 Reward:  [-3.10981929]
# Episode:  385 Time:  200 Reward:  [-898.12982772]
# Episode:  386 Time:  200 Reward:  [-821.22852833]
# Episode:  387 Time:  200 Reward:  [-1125.01680287]
# Episode:  388 Time:  200 Reward:  [-1192.06491981]
# Episode:  389 Time:  200 Reward:  [-1183.52918096]
# Episode:  390 Time:  200 Reward:  [-6.6230252]
# Episode:  391 Time:  200 Reward:  [-135.82126852]
# Episode:  392 Time:  200 Reward:  [-613.96277161]
# Episode:  393 Time:  200 Reward:  [-740.16234727]
# Episode:  394 Time:  200 Reward:  [-1072.03147682]
# Episode:  395 Time:  200 Reward:  [-1059.58479306]
# Episode:  396 Time:  200 Reward:  [-1218.2734427]
# Episode:  397 Time:  200 Reward:  [-1209.99301989]
# Episode:  398 Time:  200 Reward:  [-380.24692863]
# Episode:  399 Time:  200 Reward:  [-1219.65010755]
# Episode:  400 Time:  200 Reward:  [-920.76921014]
# Episode:  401 Time:  200 Reward:  [-131.77038798]
# Episode:  402 Time:  200 Reward:  [-543.56441264]
# Episode:  403 Time:  200 Reward:  [-131.07554565]
# Episode:  404 Time:  200 Reward:  [-373.84772821]
# Episode:  405 Time:  200 Reward:  [-4.82837521]
# Episode:  406 Time:  200 Reward:  [-128.30880833]
# Episode:  407 Time:  200 Reward:  [-380.98714132]
# Episode:  408 Time:  200 Reward:  [-3.98318018]
# Episode:  409 Time:  200 Reward:  [-132.03117289]
# Episode:  410 Time:  200 Reward:  [-502.72464178]
# Episode:  411 Time:  200 Reward:  [-519.57337754]
# Episode:  412 Time:  200 Reward:  [-258.52818053]
# Episode:  413 Time:  200 Reward:  [-394.32986455]
# Episode:  414 Time:  200 Reward:  [-501.83518507]
# Episode:  415 Time:  200 Reward:  [-257.92931667]
# Episode:  416 Time:  200 Reward:  [-259.01387629]
# Episode:  417 Time:  200 Reward:  [-570.44934504]
# Episode:  418 Time:  200 Reward:  [-522.76407865]
# Episode:  419 Time:  200 Reward:  [-133.47833009]
# Episode:  420 Time:  200 Reward:  [-376.69421828]
# Episode:  421 Time:  200 Reward:  [-132.43506351]
# Episode:  422 Time:  200 Reward:  [-131.45846174]
# Episode:  423 Time:  200 Reward:  [-269.25389466]
# Episode:  424 Time:  200 Reward:  [-381.69894171]
# Episode:  425 Time:  200 Reward:  [-389.11505954]
# Episode:  426 Time:  200 Reward:  [-371.34889873]
# Episode:  427 Time:  200 Reward:  [-381.20537903]
# Episode:  428 Time:  200 Reward:  [-256.02290328]
# Episode:  429 Time:  200 Reward:  [-255.0616114]
# Episode:  430 Time:  200 Reward:  [-372.04831358]
# Episode:  431 Time:  200 Reward:  [-3.228708]
# Episode:  432 Time:  200 Reward:  [-3.6885021]
# Episode:  433 Time:  200 Reward:  [-121.87271107]
# Episode:  434 Time:  200 Reward:  [-120.49901566]
# Episode:  435 Time:  200 Reward:  [-378.62541469]
# Episode:  436 Time:  200 Reward:  [-767.47278552]
# Episode:  437 Time:  200 Reward:  [-414.6922211]
# Episode:  438 Time:  200 Reward:  [-375.84773555]
# Episode:  439 Time:  200 Reward:  [-128.85532854]
# Episode:  440 Time:  200 Reward:  [-127.6746505]
# Episode:  441 Time:  200 Reward:  [-133.13641754]
# Episode:  442 Time:  200 Reward:  [-253.85749902]
# Episode:  443 Time:  200 Reward:  [-408.51801011]
# Episode:  444 Time:  200 Reward:  [-130.58698112]
# Episode:  445 Time:  200 Reward:  [-252.08668905]
# Episode:  446 Time:  200 Reward:  [-380.92297169]
# Episode:  447 Time:  200 Reward:  [-133.04709328]
# Episode:  448 Time:  200 Reward:  [-591.82229285]
# Episode:  449 Time:  200 Reward:  [-254.11675549]
# Episode:  450 Time:  200 Reward:  [-0.4111265]
# Episode:  451 Time:  200 Reward:  [-506.25546406]
# Episode:  452 Time:  200 Reward:  [-383.24808406]
# Episode:  453 Time:  200 Reward:  [-128.54789587]
# Episode:  454 Time:  200 Reward:  [-386.4571156]
# Episode:  455 Time:  200 Reward:  [-251.35993444]
# Episode:  456 Time:  200 Reward:  [-382.55870489]
# Episode:  457 Time:  200 Reward:  [-130.30423279]
# Episode:  458 Time:  200 Reward:  [-4.25900641]
# Episode:  459 Time:  200 Reward:  [-3.49159242]
# Episode:  460 Time:  200 Reward:  [-257.42210986]
# Episode:  461 Time:  200 Reward:  [-661.83107506]
# Episode:  462 Time:  200 Reward:  [-509.45239208]
# Episode:  463 Time:  200 Reward:  [-247.32388502]
# Episode:  464 Time:  200 Reward:  [-127.65714707]
# Episode:  465 Time:  200 Reward:  [-0.92990197]
# Episode:  466 Time:  200 Reward:  [-410.99340537]
# Episode:  467 Time:  200 Reward:  [-132.3461538]
# Episode:  468 Time:  200 Reward:  [-2.37127891]
# Episode:  469 Time:  200 Reward:  [-927.14579131]
# Episode:  470 Time:  200 Reward:  [-375.89904355]
# Episode:  471 Time:  200 Reward:  [-495.23737277]
# Episode:  472 Time:  200 Reward:  [-662.30361758]
# Episode:  473 Time:  200 Reward:  [-382.95672743]
# Episode:  474 Time:  200 Reward:  [-126.88866887]
# Episode:  475 Time:  200 Reward:  [-375.41119329]
# Episode:  476 Time:  200 Reward:  [-124.87090876]
# Episode:  477 Time:  200 Reward:  [-129.23068335]
# Episode:  478 Time:  200 Reward:  [-133.01680672]
# Episode:  479 Time:  200 Reward:  [-134.99206506]
# Episode:  480 Time:  200 Reward:  [-119.61127025]
# Episode:  481 Time:  200 Reward:  [-0.56205313]
# Episode:  482 Time:  200 Reward:  [-248.0530671]
# Episode:  483 Time:  200 Reward:  [-260.66911851]
# Episode:  484 Time:  200 Reward:  [-402.10019875]
# Episode:  485 Time:  200 Reward:  [-333.14151896]
# Episode:  486 Time:  200 Reward:  [-132.02018382]
# Episode:  487 Time:  200 Reward:  [-1144.7320278]
# Episode:  488 Time:  200 Reward:  [-128.36241367]
# Episode:  489 Time:  200 Reward:  [-1131.59816447]
# Episode:  490 Time:  200 Reward:  [-132.46104749]
# Episode:  491 Time:  200 Reward:  [-256.84451215]
# Episode:  492 Time:  200 Reward:  [-120.61450718]
# Episode:  493 Time:  200 Reward:  [-261.48888513]
# Episode:  494 Time:  200 Reward:  [-129.374835]
# Episode:  495 Time:  200 Reward:  [-655.42214427]
# Episode:  496 Time:  200 Reward:  [-3.38143786]
# Episode:  497 Time:  200 Reward:  [-129.54969411]
# Episode:  498 Time:  200 Reward:  [-1.59776035]
# Episode:  499 Time:  200 Reward:  [-244.30341602]
# Episode:  500 Time:  200 Reward:  [-129.82458564]
# Episode:  501 Time:  200 Reward:  [-2.24282633]
# Episode:  502 Time:  200 Reward:  [-130.44525377]
# Episode:  503 Time:  200 Reward:  [-977.81988964]
# Episode:  504 Time:  200 Reward:  [-820.70414456]
# Episode:  505 Time:  200 Reward:  [-925.36976297]
# Episode:  506 Time:  200 Reward:  [-257.53572079]
# Episode:  507 Time:  200 Reward:  [-408.13300879]
# Episode:  508 Time:  200 Reward:  [-2.26046441]
# Episode:  509 Time:  200 Reward:  [-256.271194]
# Episode:  510 Time:  200 Reward:  [-1.2739379]
# Episode:  511 Time:  200 Reward:  [-521.65958487]
# Episode:  512 Time:  200 Reward:  [-404.38227421]
# Episode:  513 Time:  200 Reward:  [-815.16793226]
# Episode:  514 Time:  200 Reward:  [-549.24371316]
# Episode:  515 Time:  200 Reward:  [-121.39332766]
# Episode:  516 Time:  200 Reward:  [-1.92298071]
# Episode:  517 Time:  200 Reward:  [-127.94544032]
# Episode:  518 Time:  200 Reward:  [-246.70550885]
# Episode:  519 Time:  200 Reward:  [-244.62925506]
# Episode:  520 Time:  200 Reward:  [-0.45251685]
# Episode:  521 Time:  200 Reward:  [-129.88019618]
# Episode:  522 Time:  200 Reward:  [-649.71211235]
# Episode:  523 Time:  200 Reward:  [-397.73780871]
# Episode:  524 Time:  200 Reward:  [-381.40134748]
# Episode:  525 Time:  200 Reward:  [-752.47462664]
# Episode:  526 Time:  200 Reward:  [-254.71129332]
# Episode:  527 Time:  200 Reward:  [-377.53024533]
# Episode:  528 Time:  200 Reward:  [-253.79635984]
# Episode:  529 Time:  200 Reward:  [-776.71455138]
# Episode:  530 Time:  200 Reward:  [-124.31765455]
# Episode:  531 Time:  200 Reward:  [-1.31662575]
# Episode:  532 Time:  200 Reward:  [-406.44981053]
# Episode:  533 Time:  200 Reward:  [-128.46324883]
# Episode:  534 Time:  200 Reward:  [-1182.03228839]
# Episode:  535 Time:  200 Reward:  [-1.76479325]
# Episode:  536 Time:  200 Reward:  [-1.29397507]
# Episode:  537 Time:  200 Reward:  [-392.59385115]
# Episode:  538 Time:  200 Reward:  [-1062.91453109]
# Episode:  539 Time:  200 Reward:  [-3.40777208]
# Episode:  540 Time:  200 Reward:  [-120.84600776]
# Episode:  541 Time:  200 Reward:  [-127.83686133]
# Episode:  542 Time:  200 Reward:  [-127.0243885]
# Episode:  543 Time:  200 Reward:  [-1075.94864998]
# Episode:  544 Time:  200 Reward:  [-1187.03514695]
# Episode:  545 Time:  200 Reward:  [-381.98290851]
# Episode:  546 Time:  200 Reward:  [-379.94179981]
# Episode:  547 Time:  200 Reward:  [-362.29411549]
# Episode:  548 Time:  200 Reward:  [-1191.61616081]
# Episode:  549 Time:  200 Reward:  [-128.85927051]
# Episode:  550 Time:  200 Reward:  [-260.78636421]
# Episode:  551 Time:  200 Reward:  [-1191.22751864]
# Episode:  552 Time:  200 Reward:  [-1187.4639273]
# Episode:  553 Time:  200 Reward:  [-1170.80581385]
# Episode:  554 Time:  200 Reward:  [-1072.99120978]
# Episode:  555 Time:  200 Reward:  [-1086.98214392]
# Episode:  556 Time:  200 Reward:  [-519.57032978]
# Episode:  557 Time:  200 Reward:  [-395.31349379]
# Episode:  558 Time:  200 Reward:  [-252.00225563]
# Episode:  559 Time:  200 Reward:  [-130.4102163]
# Episode:  560 Time:  200 Reward:  [-424.54506946]
# Episode:  561 Time:  200 Reward:  [-0.72550453]
# Episode:  562 Time:  200 Reward:  [-391.03356186]
# Episode:  563 Time:  200 Reward:  [-257.83647604]
# Episode:  564 Time:  200 Reward:  [-514.47112428]
# Episode:  565 Time:  200 Reward:  [-256.69522108]
# Episode:  566 Time:  200 Reward:  [-131.95722537]
# Episode:  567 Time:  200 Reward:  [-125.53605598]
# Episode:  568 Time:  200 Reward:  [-376.79273001]
# Episode:  569 Time:  200 Reward:  [-400.26138623]
# Episode:  570 Time:  200 Reward:  [-258.95546215]
# Episode:  571 Time:  200 Reward:  [-382.09383792]
# Episode:  572 Time:  200 Reward:  [-132.62275985]
# Episode:  573 Time:  200 Reward:  [-2.70579225]
# Episode:  574 Time:  200 Reward:  [-132.96882206]
# Episode:  575 Time:  200 Reward:  [-130.54696421]
# Episode:  576 Time:  200 Reward:  [-126.86570777]
# Episode:  577 Time:  200 Reward:  [-503.86361628]
# Episode:  578 Time:  200 Reward:  [-126.75468625]
# Episode:  579 Time:  200 Reward:  [-128.15342651]
# Episode:  580 Time:  200 Reward:  [-124.78896938]
# Episode:  581 Time:  200 Reward:  [-125.95002926]
# Episode:  582 Time:  200 Reward:  [-929.08999185]
# Episode:  583 Time:  200 Reward:  [-6.94882765]
# Episode:  584 Time:  200 Reward:  [-259.96444434]
# Episode:  585 Time:  200 Reward:  [-127.5373301]
# Episode:  586 Time:  200 Reward:  [-374.58299129]
# Episode:  587 Time:  200 Reward:  [-259.32912096]
# Episode:  588 Time:  200 Reward:  [-258.71849988]
# Episode:  589 Time:  200 Reward:  [-371.91615575]
# Episode:  590 Time:  200 Reward:  [-257.8215528]
# Episode:  591 Time:  200 Reward:  [-365.35674067]
# Episode:  592 Time:  200 Reward:  [-255.88754402]
# Episode:  593 Time:  200 Reward:  [-255.07024486]
# Episode:  594 Time:  200 Reward:  [-125.54061726]
# Episode:  595 Time:  200 Reward:  [-377.86305758]
# Episode:  596 Time:  200 Reward:  [-258.69259429]
# Episode:  597 Time:  200 Reward:  [-127.90855415]
# Episode:  598 Time:  200 Reward:  [-496.45373659]
# Episode:  599 Time:  200 Reward:  [-3.31296502]
# Episode:  600 Time:  200 Reward:  [-125.31045239]
# Episode:  601 Time:  200 Reward:  [-394.22324145]
# Episode:  602 Time:  200 Reward:  [-246.20813927]
# Episode:  603 Time:  200 Reward:  [-380.80782214]
# Episode:  604 Time:  200 Reward:  [-0.61089628]
# Episode:  605 Time:  200 Reward:  [-259.9991534]
# Episode:  606 Time:  200 Reward:  [-646.17973017]
# Episode:  607 Time:  200 Reward:  [-253.41157086]
# Episode:  608 Time:  200 Reward:  [-119.74440224]
# Episode:  609 Time:  200 Reward:  [-127.3255391]
# Episode:  610 Time:  200 Reward:  [-1077.27818436]
# Episode:  611 Time:  200 Reward:  [-1210.13793175]
# Episode:  612 Time:  200 Reward:  [-1284.52981688]
# Episode:  613 Time:  200 Reward:  [-1213.94926314]
# Episode:  614 Time:  200 Reward:  [-1317.92611659]
# Episode:  615 Time:  200 Reward:  [-1249.5045625]
# Episode:  616 Time:  200 Reward:  [-1055.88034804]
# Episode:  617 Time:  200 Reward:  [-1203.56473267]
# Episode:  618 Time:  200 Reward:  [-791.25295273]
# Episode:  619 Time:  200 Reward:  [-1236.77856028]
# Episode:  620 Time:  200 Reward:  [-136.50618904]
# Episode:  621 Time:  200 Reward:  [-1201.7350452]
# Episode:  622 Time:  200 Reward:  [-124.61686982]
# Episode:  623 Time:  200 Reward:  [-1268.55767846]
# Episode:  624 Time:  200 Reward:  [-252.23937756]
# Episode:  625 Time:  200 Reward:  [-765.44579308]
# Episode:  626 Time:  200 Reward:  [-960.24263597]
# Episode:  627 Time:  200 Reward:  [-1304.72110416]
# Episode:  628 Time:  200 Reward:  [-1238.29712497]
# Episode:  629 Time:  200 Reward:  [-1156.82609265]
# Episode:  630 Time:  200 Reward:  [-393.53461837]
# Episode:  631 Time:  200 Reward:  [-245.31644623]
# Episode:  632 Time:  200 Reward:  [-924.24208023]
# Episode:  633 Time:  200 Reward:  [-6.65667908]
# Episode:  634 Time:  200 Reward:  [-9.45059375]
# Episode:  635 Time:  200 Reward:  [-405.30851373]
# Episode:  636 Time:  200 Reward:  [-907.80978514]
# Episode:  637 Time:  200 Reward:  [-1205.40555812]
# Episode:  638 Time:  200 Reward:  [-452.41574307]
# Episode:  639 Time:  200 Reward:  [-765.19314983]
# Episode:  640 Time:  200 Reward:  [-796.59194478]
# Episode:  641 Time:  200 Reward:  [-383.79255406]
# Episode:  642 Time:  200 Reward:  [-373.66221846]
# Episode:  643 Time:  200 Reward:  [-517.81614175]
# Episode:  644 Time:  200 Reward:  [-127.76338639]
# Episode:  645 Time:  200 Reward:  [-247.22523869]
# Episode:  646 Time:  200 Reward:  [-895.154325]
# Episode:  647 Time:  200 Reward:  [-126.30159887]
# Episode:  648 Time:  200 Reward:  [-127.33574117]
# Episode:  649 Time:  200 Reward:  [-263.60821235]
# Episode:  650 Time:  200 Reward:  [-1031.44462305]
# Episode:  651 Time:  200 Reward:  [-434.68031971]
# Episode:  652 Time:  200 Reward:  [-249.87555834]
# Episode:  653 Time:  200 Reward:  [-253.18925788]
# Episode:  654 Time:  200 Reward:  [-249.67500757]
# Episode:  655 Time:  200 Reward:  [-132.44713571]
# Episode:  656 Time:  200 Reward:  [-252.24657677]
# Episode:  657 Time:  200 Reward:  [-626.48045275]
# Episode:  658 Time:  200 Reward:  [-583.57190207]
# Episode:  659 Time:  200 Reward:  [-137.45780681]
# Episode:  660 Time:  200 Reward:  [-137.30451465]
# Episode:  661 Time:  200 Reward:  [-15.74767872]
# Episode:  662 Time:  200 Reward:  [-257.42500134]
# Episode:  663 Time:  200 Reward:  [-367.56685231]
# Episode:  664 Time:  200 Reward:  [-650.59802975]
# Episode:  665 Time:  200 Reward:  [-447.83860077]
# Episode:  666 Time:  200 Reward:  [-1.97675784]
# Episode:  667 Time:  200 Reward:  [-260.06793992]
# Episode:  668 Time:  200 Reward:  [-389.22243374]
# Episode:  669 Time:  200 Reward:  [-391.64667755]
# Episode:  670 Time:  200 Reward:  [-249.28971229]
# Episode:  671 Time:  200 Reward:  [-262.18584405]
# Episode:  672 Time:  200 Reward:  [-1.7306845]
# Episode:  673 Time:  200 Reward:  [-250.80385226]
# Episode:  674 Time:  200 Reward:  [-128.55761373]
# Episode:  675 Time:  200 Reward:  [-128.47755276]
# Episode:  676 Time:  200 Reward:  [-4.46519347]
# Episode:  677 Time:  200 Reward:  [-132.14606794]
# Episode:  678 Time:  200 Reward:  [-257.28348499]
# Episode:  679 Time:  200 Reward:  [-129.38189309]
# Episode:  680 Time:  200 Reward:  [-252.56326892]
# Episode:  681 Time:  200 Reward:  [-239.39717168]
# Episode:  682 Time:  200 Reward:  [-252.86340085]
# Episode:  683 Time:  200 Reward:  [-323.35889273]
# Episode:  684 Time:  200 Reward:  [-126.27862917]
# Episode:  685 Time:  200 Reward:  [-0.58685354]
# Episode:  686 Time:  200 Reward:  [-131.28392632]
# Episode:  687 Time:  200 Reward:  [-1.68324574]
# Episode:  688 Time:  200 Reward:  [-252.30181275]
# Episode:  689 Time:  200 Reward:  [-379.61198001]
# Episode:  690 Time:  200 Reward:  [-250.82564773]
# Episode:  691 Time:  200 Reward:  [-128.16555745]
# Episode:  692 Time:  200 Reward:  [-125.93824935]
# Episode:  693 Time:  200 Reward:  [-250.40017889]
# Episode:  694 Time:  200 Reward:  [-245.75035802]
# Episode:  695 Time:  200 Reward:  [-124.63486414]
# Episode:  696 Time:  200 Reward:  [-654.03298484]
# Episode:  697 Time:  200 Reward:  [-1.17050093]
# Episode:  698 Time:  200 Reward:  [-390.04936831]
# Episode:  699 Time:  200 Reward:  [-421.33700063]
# Episode:  700 Time:  200 Reward:  [-260.9261769]
# Episode:  701 Time:  200 Reward:  [-379.08719459]
# Episode:  702 Time:  200 Reward:  [-134.20666743]
# Episode:  703 Time:  200 Reward:  [-133.33732696]
# Episode:  704 Time:  200 Reward:  [-129.30693817]
# Episode:  705 Time:  200 Reward:  [-127.77362182]
# Episode:  706 Time:  200 Reward:  [-127.1822964]
# Episode:  707 Time:  200 Reward:  [-126.77812829]
# Episode:  708 Time:  200 Reward:  [-244.30230781]
# Episode:  709 Time:  200 Reward:  [-369.26319571]
# Episode:  710 Time:  200 Reward:  [-368.36439614]
# Episode:  711 Time:  200 Reward:  [-364.42711721]
# Episode:  712 Time:  200 Reward:  [-390.2338782]
# Episode:  713 Time:  200 Reward:  [-2.17764732]
# Episode:  714 Time:  200 Reward:  [-130.29284027]
# Episode:  715 Time:  200 Reward:  [-897.99732653]
# Episode:  716 Time:  200 Reward:  [-130.61209118]
# Episode:  717 Time:  200 Reward:  [-504.85176564]
# Episode:  718 Time:  200 Reward:  [-248.12634232]
# Episode:  719 Time:  200 Reward:  [-4.0408839]
# Episode:  720 Time:  200 Reward:  [-5.08457504]
# Episode:  721 Time:  200 Reward:  [-404.11308378]
# Episode:  722 Time:  200 Reward:  [-259.21079807]
# Episode:  723 Time:  200 Reward:  [-133.58252378]
# Episode:  724 Time:  200 Reward:  [-122.95618447]
# Episode:  725 Time:  200 Reward:  [-263.05021942]
# Episode:  726 Time:  200 Reward:  [-129.29550346]
# Episode:  727 Time:  200 Reward:  [-3.18437359]
# Episode:  728 Time:  200 Reward:  [-3.28503217]
# Episode:  729 Time:  200 Reward:  [-255.95794541]
# Episode:  730 Time:  200 Reward:  [-258.082455]
# Episode:  731 Time:  200 Reward:  [-1047.31146489]
# Episode:  732 Time:  200 Reward:  [-923.04483202]
# Episode:  733 Time:  200 Reward:  [-983.45951832]
# Episode:  734 Time:  200 Reward:  [-502.57657245]
# Episode:  735 Time:  200 Reward:  [-254.92454367]
# Episode:  736 Time:  200 Reward:  [-261.12691578]
# Episode:  737 Time:  200 Reward:  [-134.70388213]
# Episode:  738 Time:  200 Reward:  [-132.33101928]
# Episode:  739 Time:  200 Reward:  [-7.1435977]
# Episode:  740 Time:  200 Reward:  [-1018.43761532]
# Episode:  741 Time:  200 Reward:  [-255.8951648]
# Episode:  742 Time:  200 Reward:  [-523.03456068]
# Episode:  743 Time:  200 Reward:  [-249.53284592]
# Episode:  744 Time:  200 Reward:  [-306.54329367]
# Episode:  745 Time:  200 Reward:  [-458.48244003]
# Episode:  746 Time:  200 Reward:  [-124.61546303]
# Episode:  747 Time:  200 Reward:  [-1180.10986341]
# Episode:  748 Time:  200 Reward:  [-510.00679215]
# Episode:  749 Time:  200 Reward:  [-128.14586987]
# Episode:  750 Time:  200 Reward:  [-127.1138742]
# Episode:  751 Time:  200 Reward:  [-130.2329396]
# Episode:  752 Time:  200 Reward:  [-130.06787236]
# Episode:  753 Time:  200 Reward:  [-129.0290002]
# Episode:  754 Time:  200 Reward:  [-129.02398515]
# Episode:  755 Time:  200 Reward:  [-3.61566738]
# Episode:  756 Time:  200 Reward:  [-128.91904753]
# Episode:  757 Time:  200 Reward:  [-129.20800063]
# Episode:  758 Time:  200 Reward:  [-4.00891341]
# Episode:  759 Time:  200 Reward:  [-242.06636687]
# Episode:  760 Time:  200 Reward:  [-258.39847478]
# Episode:  761 Time:  200 Reward:  [-5.15711811]
# Episode:  762 Time:  200 Reward:  [-132.72867283]
# Episode:  763 Time:  200 Reward:  [-362.30648693]
# Episode:  764 Time:  200 Reward:  [-916.94191064]
# Episode:  765 Time:  200 Reward:  [-540.60567948]
# Episode:  766 Time:  200 Reward:  [-420.5429284]
# Episode:  767 Time:  200 Reward:  [-134.55456031]
# Episode:  768 Time:  200 Reward:  [-129.78629812]
# Episode:  769 Time:  200 Reward:  [-392.37946781]
# Episode:  770 Time:  200 Reward:  [-520.71725844]
# Episode:  771 Time:  200 Reward:  [-259.69849664]
# Episode:  772 Time:  200 Reward:  [-265.0556142]
# Episode:  773 Time:  200 Reward:  [-420.38587836]
# Episode:  774 Time:  200 Reward:  [-272.72453559]
# Episode:  775 Time:  200 Reward:  [-372.48671696]
# Episode:  776 Time:  200 Reward:  [-9.45175689]
# Episode:  777 Time:  200 Reward:  [-8.43955574]
# Episode:  778 Time:  200 Reward:  [-1059.64940161]
# Episode:  779 Time:  200 Reward:  [-5.52705586]
# Episode:  780 Time:  200 Reward:  [-410.38057739]
# Episode:  781 Time:  200 Reward:  [-136.87069338]
# Episode:  782 Time:  200 Reward:  [-139.6855998]
# Episode:  783 Time:  200 Reward:  [-266.64825292]
# Episode:  784 Time:  200 Reward:  [-265.96587438]
# Episode:  785 Time:  200 Reward:  [-140.1620797]
# Episode:  786 Time:  200 Reward:  [-426.82182074]
# Episode:  787 Time:  200 Reward:  [-128.95568838]
# Episode:  788 Time:  200 Reward:  [-132.95567201]
# Episode:  789 Time:  200 Reward:  [-130.97736728]
# Episode:  790 Time:  200 Reward:  [-1083.71220354]
# Episode:  791 Time:  200 Reward:  [-3.60286671]
# Episode:  792 Time:  200 Reward:  [-266.25110093]
# Episode:  793 Time:  200 Reward:  [-129.12103245]
# Episode:  794 Time:  200 Reward:  [-260.65534725]
# Episode:  795 Time:  200 Reward:  [-248.15872514]
# Episode:  796 Time:  200 Reward:  [-132.54049637]
# Episode:  797 Time:  200 Reward:  [-123.04921037]
# Episode:  798 Time:  200 Reward:  [-552.33862833]
# Episode:  799 Time:  200 Reward:  [-387.81815932]
# Episode:  800 Time:  200 Reward:  [-128.76760397]
# Episode:  801 Time:  200 Reward:  [-130.39714416]
# Episode:  802 Time:  200 Reward:  [-531.05805442]
# Episode:  803 Time:  200 Reward:  [-0.44865078]
# Episode:  804 Time:  200 Reward:  [-375.77749727]
# Episode:  805 Time:  200 Reward:  [-124.51171237]
# Episode:  806 Time:  200 Reward:  [-134.43926286]
# Episode:  807 Time:  200 Reward:  [-127.36582128]
# Episode:  808 Time:  200 Reward:  [-422.85020329]
# Episode:  809 Time:  200 Reward:  [-131.9873567]
# Episode:  810 Time:  200 Reward:  [-125.41502847]
# Episode:  811 Time:  200 Reward:  [-484.64833969]
# Episode:  812 Time:  200 Reward:  [-0.33853746]
# Episode:  813 Time:  200 Reward:  [-388.97746339]
# Episode:  814 Time:  200 Reward:  [-375.01613347]
# Episode:  815 Time:  200 Reward:  [-380.14102177]
# Episode:  816 Time:  200 Reward:  [-376.03101849]
# Episode:  817 Time:  200 Reward:  [-270.35369022]
# Episode:  818 Time:  200 Reward:  [-384.87352044]
# Episode:  819 Time:  200 Reward:  [-257.21468969]
# Episode:  820 Time:  200 Reward:  [-258.54517519]
# Episode:  821 Time:  200 Reward:  [-132.41697178]
# Episode:  822 Time:  200 Reward:  [-121.75563714]
# Episode:  823 Time:  200 Reward:  [-128.36103986]
# Episode:  824 Time:  200 Reward:  [-126.56731746]
# Episode:  825 Time:  200 Reward:  [-377.22114443]
# Episode:  826 Time:  200 Reward:  [-124.48196221]
# Episode:  827 Time:  200 Reward:  [-262.55527151]
# Episode:  828 Time:  200 Reward:  [-123.78164436]
# Episode:  829 Time:  200 Reward:  [-129.40886967]
# Episode:  830 Time:  200 Reward:  [-129.11675417]
# Episode:  831 Time:  200 Reward:  [-131.07119271]
# Episode:  832 Time:  200 Reward:  [-131.148331]
# Episode:  833 Time:  200 Reward:  [-493.58356594]
# Episode:  834 Time:  200 Reward:  [-129.46745684]
# Episode:  835 Time:  200 Reward:  [-131.79110754]
# Episode:  836 Time:  200 Reward:  [-125.80370196]
# Episode:  837 Time:  200 Reward:  [-262.82808687]
# Episode:  838 Time:  200 Reward:  [-446.84946443]
# Episode:  839 Time:  200 Reward:  [-390.63008742]
# Episode:  840 Time:  200 Reward:  [-251.1320587]
# Episode:  841 Time:  200 Reward:  [-129.36831829]
# Episode:  842 Time:  200 Reward:  [-268.99787114]
# Episode:  843 Time:  200 Reward:  [-253.02573169]
# Episode:  844 Time:  200 Reward:  [-372.62551163]
# Episode:  845 Time:  200 Reward:  [-125.56167277]
# Episode:  846 Time:  200 Reward:  [-380.73066119]
# Episode:  847 Time:  200 Reward:  [-124.22114686]
# Episode:  848 Time:  200 Reward:  [-242.55694056]
# Episode:  849 Time:  200 Reward:  [-252.63858619]
# Episode:  850 Time:  200 Reward:  [-257.25997635]
# Episode:  851 Time:  200 Reward:  [-390.8456107]
# Episode:  852 Time:  200 Reward:  [-261.4808265]
# Episode:  853 Time:  200 Reward:  [-246.58682651]
# Episode:  854 Time:  200 Reward:  [-126.34268286]
# Episode:  855 Time:  200 Reward:  [-131.15453693]
# Episode:  856 Time:  200 Reward:  [-257.42605684]
# Episode:  857 Time:  200 Reward:  [-362.66601696]
# Episode:  858 Time:  200 Reward:  [-251.96349568]
# Episode:  859 Time:  200 Reward:  [-246.90128361]
# Episode:  860 Time:  200 Reward:  [-379.6305623]
# Episode:  861 Time:  200 Reward:  [-923.27958467]
# Episode:  862 Time:  200 Reward:  [-124.25402432]
# Episode:  863 Time:  200 Reward:  [-411.31303494]
# Episode:  864 Time:  200 Reward:  [-302.04437235]
# Episode:  865 Time:  200 Reward:  [-125.93562672]
# Episode:  866 Time:  200 Reward:  [-261.57871342]
# Episode:  867 Time:  200 Reward:  [-122.88323936]
# Episode:  868 Time:  200 Reward:  [-356.70399829]
# Episode:  869 Time:  200 Reward:  [-129.24760682]
# Episode:  870 Time:  200 Reward:  [-516.79577202]
# Episode:  871 Time:  200 Reward:  [-127.45908926]
# Episode:  872 Time:  200 Reward:  [-131.15985996]
# Episode:  873 Time:  200 Reward:  [-127.93842314]
# Episode:  874 Time:  200 Reward:  [-380.41860069]
# Episode:  875 Time:  200 Reward:  [-249.19361503]
# Episode:  876 Time:  200 Reward:  [-748.61640908]
# Episode:  877 Time:  200 Reward:  [-248.51430487]
# Episode:  878 Time:  200 Reward:  [-130.19319247]
# Episode:  879 Time:  200 Reward:  [-552.11410041]
# Episode:  880 Time:  200 Reward:  [-122.78019899]
# Episode:  881 Time:  200 Reward:  [-127.21326678]
# Episode:  882 Time:  200 Reward:  [-258.58132132]
# Episode:  883 Time:  200 Reward:  [-1033.6018223]
# Episode:  884 Time:  200 Reward:  [-0.69941404]
# Episode:  885 Time:  200 Reward:  [-258.91474992]
# Episode:  886 Time:  200 Reward:  [-128.57222037]
# Episode:  887 Time:  200 Reward:  [-133.24639928]
# Episode:  888 Time:  200 Reward:  [-1.72238523]
# Episode:  889 Time:  200 Reward:  [-256.25075665]
# Episode:  890 Time:  200 Reward:  [-128.967209]
# Episode:  891 Time:  200 Reward:  [-126.54315839]
# Episode:  892 Time:  200 Reward:  [-128.05562337]
# Episode:  893 Time:  200 Reward:  [-127.23624655]
# Episode:  894 Time:  200 Reward:  [-1.29078107]
# Episode:  895 Time:  200 Reward:  [-2.46063052]
# Episode:  896 Time:  200 Reward:  [-123.54038053]
# Episode:  897 Time:  200 Reward:  [-798.7331311]
# Episode:  898 Time:  200 Reward:  [-268.48827724]
# Episode:  899 Time:  200 Reward:  [-780.71469102]
# Episode:  900 Time:  200 Reward:  [-132.08203149]
# Episode:  901 Time:  200 Reward:  [-509.30494757]
# Episode:  902 Time:  200 Reward:  [-245.69776358]
# Episode:  903 Time:  200 Reward:  [-132.24120206]
# Episode:  904 Time:  200 Reward:  [-504.49266705]
# Episode:  905 Time:  200 Reward:  [-133.37392781]
# Episode:  906 Time:  200 Reward:  [-131.05424958]
# Episode:  907 Time:  200 Reward:  [-130.41770037]
# Episode:  908 Time:  200 Reward:  [-525.39837458]
# Episode:  909 Time:  200 Reward:  [-127.23258634]
# Episode:  910 Time:  200 Reward:  [-131.35572083]
# Episode:  911 Time:  200 Reward:  [-126.20429542]
# Episode:  912 Time:  200 Reward:  [-132.54250552]
# Episode:  913 Time:  200 Reward:  [-1049.53792194]
# Episode:  914 Time:  200 Reward:  [-368.52416138]
# Episode:  915 Time:  200 Reward:  [-252.19257527]
# Episode:  916 Time:  200 Reward:  [-377.48588884]
# Episode:  917 Time:  200 Reward:  [-1044.93005905]
# Episode:  918 Time:  200 Reward:  [-1163.88659235]
# Episode:  919 Time:  200 Reward:  [-0.61912808]
# Episode:  920 Time:  200 Reward:  [-126.41272471]
# Episode:  921 Time:  200 Reward:  [-1.19223067]
# Episode:  922 Time:  200 Reward:  [-0.78829687]
# Episode:  923 Time:  200 Reward:  [-1171.0647866]
# Episode:  924 Time:  200 Reward:  [-1317.46519468]
# Episode:  925 Time:  200 Reward:  [-128.34883739]
# Episode:  926 Time:  200 Reward:  [-1.56283961]
# Episode:  927 Time:  200 Reward:  [-129.83060672]
# Episode:  928 Time:  200 Reward:  [-1116.00119211]
# Episode:  929 Time:  200 Reward:  [-938.68293058]
# Episode:  930 Time:  200 Reward:  [-127.2456495]
# Episode:  931 Time:  200 Reward:  [-128.36071689]
# Episode:  932 Time:  200 Reward:  [-128.80510533]
# Episode:  933 Time:  200 Reward:  [-654.20960119]
# Episode:  934 Time:  200 Reward:  [-1.29307254]
# Episode:  935 Time:  200 Reward:  [-398.5632676]
# Episode:  936 Time:  200 Reward:  [-0.7029774]
# Episode:  937 Time:  200 Reward:  [-126.49600289]
# Episode:  938 Time:  200 Reward:  [-129.8180171]
# Episode:  939 Time:  200 Reward:  [-124.31301425]
# Episode:  940 Time:  200 Reward:  [-246.76230922]
# Episode:  941 Time:  200 Reward:  [-121.78726168]
# Episode:  942 Time:  200 Reward:  [-443.32885545]
# Episode:  943 Time:  200 Reward:  [-248.35486425]
# Episode:  944 Time:  200 Reward:  [-129.70165673]
# Episode:  945 Time:  200 Reward:  [-129.11583653]
# Episode:  946 Time:  200 Reward:  [-385.92743008]
# Episode:  947 Time:  200 Reward:  [-2.13346687]
# Episode:  948 Time:  200 Reward:  [-375.71716678]
# Episode:  949 Time:  200 Reward:  [-241.27921564]
# Episode:  950 Time:  200 Reward:  [-129.50590074]
# Episode:  951 Time:  200 Reward:  [-257.5800725]
# Episode:  952 Time:  200 Reward:  [-263.54101934]
# Episode:  953 Time:  200 Reward:  [-247.88426644]
# Episode:  954 Time:  200 Reward:  [-238.12236823]
# Episode:  955 Time:  200 Reward:  [-1057.76119478]
# Episode:  956 Time:  200 Reward:  [-1.81273107]
# Episode:  957 Time:  200 Reward:  [-952.96345287]
# Episode:  958 Time:  200 Reward:  [-0.99467701]
# Episode:  959 Time:  200 Reward:  [-258.04538674]
# Episode:  960 Time:  200 Reward:  [-128.85667247]
# Episode:  961 Time:  200 Reward:  [-259.50263829]
# Episode:  962 Time:  200 Reward:  [-246.10963969]
# Episode:  963 Time:  200 Reward:  [-0.59906706]
# Episode:  964 Time:  200 Reward:  [-124.86988012]
# Episode:  965 Time:  200 Reward:  [-1.32804713]
# Episode:  966 Time:  200 Reward:  [-124.53024479]
# Episode:  967 Time:  200 Reward:  [-265.4571729]
# Episode:  968 Time:  200 Reward:  [-363.8370283]
# Episode:  969 Time:  200 Reward:  [-127.2134667]
# Episode:  970 Time:  200 Reward:  [-0.37159478]
# Episode:  971 Time:  200 Reward:  [-127.18292477]
# Episode:  972 Time:  200 Reward:  [-249.76966668]
# Episode:  973 Time:  200 Reward:  [-391.98628832]
# Episode:  974 Time:  200 Reward:  [-129.50248891]
# Episode:  975 Time:  200 Reward:  [-1179.38471209]
# Episode:  976 Time:  200 Reward:  [-129.52125436]
# Episode:  977 Time:  200 Reward:  [-1074.57548854]
# Episode:  978 Time:  200 Reward:  [-131.25071323]
# Episode:  979 Time:  200 Reward:  [-924.41503625]
# Episode:  980 Time:  200 Reward:  [-353.16917423]
# Episode:  981 Time:  200 Reward:  [-771.74350392]
# Episode:  982 Time:  200 Reward:  [-239.86489395]
# Episode:  983 Time:  200 Reward:  [-241.32016221]
# Episode:  984 Time:  200 Reward:  [-369.35577718]
# Episode:  985 Time:  200 Reward:  [-788.62545636]
# Episode:  986 Time:  200 Reward:  [-1.15281627]
# Episode:  987 Time:  200 Reward:  [-392.72025917]
# Episode:  988 Time:  200 Reward:  [-1044.60176802]
# Episode:  989 Time:  200 Reward:  [-123.82449575]
# Episode:  990 Time:  200 Reward:  [-0.73341116]
# Episode:  991 Time:  200 Reward:  [-241.55389178]
# Episode:  992 Time:  200 Reward:  [-264.08170777]
# Episode:  993 Time:  200 Reward:  [-455.27687118]
# Episode:  994 Time:  200 Reward:  [-2.7419218]
# Episode:  995 Time:  200 Reward:  [-791.66675676]
# Episode:  996 Time:  200 Reward:  [-128.34628738]
# Episode:  997 Time:  200 Reward:  [-1037.43648875]
# Episode:  998 Time:  200 Reward:  [-246.17000288]
# Episode:  999 Time:  200 Reward:  [-128.20280539]
# Episode:  1000 Time:  200 Reward:  [-658.05298827]
# [array([-1105.19553534]), array([-1478.67205813]), array([-1402.12053345]), array([-1432.48778382]), array([-1226.49693289]), array([-1365.9942007]), array([-1411.9700343]), array([-1456.35231477]), array([-891.57606468]), array([-1327.97376199]), array([-1202.33904918]), array([-1316.60416265]), array([-1098.67032946]), array([-1348.05087843]), array([-1319.5373004]), array([-1109.67936223]), array([-973.90665746]), array([-1347.33037703]), array([-1087.58476281]), array([-896.13764825]), array([-1321.64719757]), array([-1016.92357661]), array([-1231.73925599]), array([-1028.75837106]), array([-980.50813656]), array([-1125.86592503]), array([-1028.80123167]), array([-1089.92829072]), array([-1146.6137358]), array([-879.34642834]), array([-1321.76275965]), array([-865.38455692]), array([-1402.7735654]), array([-1201.21848259]), array([-1080.28415142]), array([-967.29496509]), array([-747.56293841]), array([-958.83409937]), array([-1171.34361211]), array([-1075.77152743]), array([-718.56781259]), array([-850.88299509]), array([-1105.55561506]), array([-1207.08269822]), array([-1004.51127431]), array([-982.49081374]), array([-1194.66954347]), array([-1132.74097518]), array([-1073.93668907]), array([-759.46371848]), array([-855.78497877]), array([-856.27002352]), array([-762.31252674]), array([-978.27260146]), array([-1223.15031633]), array([-1141.36689138]), array([-1001.88056987]), array([-1035.99739768]), array([-753.34143894]), array([-891.41291601]), array([-852.4511074]), array([-872.18853071]), array([-811.32693413]), array([-847.30082345]), array([-864.96566486]), array([-851.60534835]), array([-814.80290044]), array([-981.57317039]), array([-860.96860955]), array([-860.9429464]), array([-752.86854391]), array([-1216.43070189]), array([-1181.62165578]), array([-879.87940445]), array([-971.8126022]), array([-1072.23619519]), array([-962.27950029]), array([-966.98969554]), array([-983.81069611]), array([-874.53680022]), array([-1243.95788199]), array([-1013.69014572]), array([-841.67589389]), array([-994.20077209]), array([-888.76864148]), array([-1107.674939]), array([-868.2087219]), array([-958.05898608]), array([-964.26733611]), array([-974.19874115]), array([-1145.03325306]), array([-742.71536284]), array([-1079.66338448]), array([-990.07580845]), array([-867.49533879]), array([-1011.20148286]), array([-771.96738647]), array([-970.07285905]), array([-877.67548388]), array([-1003.03182594]), array([-991.07096706]), array([-1078.08307348]), array([-1112.79455822]), array([-757.88180254]), array([-1040.06150611]), array([-738.86852426]), array([-995.58765173]), array([-703.95041575]), array([-759.07672751]), array([-896.81069186]), array([-967.42953706]), array([-1152.82215973]), array([-633.40968779]), array([-884.71753463]), array([-866.06734823]), array([-642.81640079]), array([-975.83464769]), array([-787.52888696]), array([-749.5708085]), array([-963.36488256]), array([-841.54037871]), array([-741.8931351]), array([-758.58768661]), array([-1087.78820861]), array([-1042.92533221]), array([-728.24786388]), array([-1245.92393339]), array([-780.35704545]), array([-1102.9433219]), array([-1131.18105191]), array([-633.92281327]), array([-1048.917749]), array([-778.51334994]), array([-1102.00774419]), array([-1083.39047767]), array([-1150.83266245]), array([-1019.61922983]), array([-759.26643671]), array([-765.99156165]), array([-885.92391628]), array([-860.4093947]), array([-642.75913771]), array([-870.55170588]), array([-850.46286128]), array([-995.59745636]), array([-867.68644247]), array([-622.91828329]), array([-777.98400226]), array([-643.19587736]), array([-986.49308838]), array([-789.46041667]), array([-505.28906323]), array([-771.08376844]), array([-504.50277847]), array([-873.75616517]), array([-890.58699438]), array([-847.6645115]), array([-505.2926398]), array([-753.72265755]), array([-631.47609172]), array([-737.70489504]), array([-502.07022296]), array([-851.11782438]), array([-758.69255888]), array([-643.06093 ...

# %%
# PPO with GAE Load and Play

import gym

def main():

    env_name = 'Pendulum-v0'
    env = gym.make(env_name)
    agent = PPOagent(env)

    agent.actor.load_weights('./save_weights/')
    agent.critic.load_weights('./save_weights/')

    time = 0
    state = env.reset()

    while True:
        action = agent.actor.predict(state)
        state, reward, done, _ = env.step(action)
        time += 1

        print('Time: ', time, 'Reward: ', reward)

        if done:
            break

    env.close()

if __name__=="__main__":
    main()
# Out:
# Model: "functional_13"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 3)]          0
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 64)           256         input_7[0][0]
# __________________________________________________________________________________________________
# dense_28 (Dense)                (None, 32)           2080        dense_27[0][0]
# __________________________________________________________________________________________________
# dense_29 (Dense)                (None, 16)           528         dense_28[0][0]
# __________________________________________________________________________________________________
# dense_30 (Dense)                (None, 1)            17          dense_29[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 1)            0           dense_30[0][0]
# __________________________________________________________________________________________________
# dense_31 (Dense)                (None, 1)            17          dense_29[0][0]
# ==================================================================================================
# Total params: 2,898
# Trainable params: 2,898
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "functional_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         [(None, 3)]               0
# _________________________________________________________________
# dense_32 (Dense)             (None, 64)                256
# _________________________________________________________________
# dense_33 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_34 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_35 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 2,881
# Trainable params: 2,881
# Non-trainable params: 0
# _________________________________________________________________
# Time:  1 Reward:  -3.7970465033765723
# Time:  2 Reward:  -4.055339916241552
# Time:  3 Reward:  -4.465063632694096
# Time:  4 Reward:  -5.088197710921628
# Time:  5 Reward:  -6.020494037813916
# Time:  6 Reward:  -7.331975537881894
# Time:  7 Reward:  -8.998010169668865
# Time:  8 Reward:  -10.931362799131685
# Time:  9 Reward:  -12.379413729755555
# Time:  10 Reward:  -11.018266364752321
# Time:  11 Reward:  -9.577266340281971
# Time:  12 Reward:  -8.115094032535344
# Time:  13 Reward:  -6.7041249633037445
# Time:  14 Reward:  -5.411833665066794
# Time:  15 Reward:  -4.284874639697593
# Time:  16 Reward:  -3.3429401906253973
# Time:  17 Reward:  -2.582306143927305
# Time:  18 Reward:  -1.9840843897195144
# Time:  19 Reward:  -1.522475680738821
# Time:  20 Reward:  -1.169886159450981
# Time:  21 Reward:  -0.899991641349481
# Time:  22 Reward:  -0.6888517105936396
# Time:  23 Reward:  -0.5163827435625556
# Time:  24 Reward:  -0.37253520693913483
# Time:  25 Reward:  -0.25557793525969247
# Time:  26 Reward:  -0.17307900043664137
# Time:  27 Reward:  -0.11700699801145456
# Time:  28 Reward:  -0.08014720170813246
# Time:  29 Reward:  -0.054884244154768676
# Time:  30 Reward:  -0.037558608276048774
# Time:  31 Reward:  -0.025721591967263657
# Time:  32 Reward:  -0.01732324616954955
# Time:  33 Reward:  -0.01171509030083625
# Time:  34 Reward:  -0.008007950313303414
# Time:  35 Reward:  -0.005542364354060172
# Time:  36 Reward:  -0.003884686486050597
# Time:  37 Reward:  -0.0027633998008417325
# Time:  38 Reward:  -0.0020620687330785976
# Time:  39 Reward:  -0.001656665568744676
# Time:  40 Reward:  -0.0014479081347311632
# Time:  41 Reward:  -0.0013642242921581955
# Time:  42 Reward:  -0.0013566633592095347
# Time:  43 Reward:  -0.0013928067724254187
# Time:  44 Reward:  -0.001451751057702658
# Time:  45 Reward:  -0.0015203710771223076
# Time:  46 Reward:  -0.0015907007488643672
# Time:  47 Reward:  -0.001658142302415345
# Time:  48 Reward:  -0.0017202549262379666
# Time:  49 Reward:  -0.001775951828734881
# Time:  50 Reward:  -0.0018249711329986517
# Time:  51 Reward:  -0.001867529611653992
# Time:  52 Reward:  -0.0019041055861002266
# Time:  53 Reward:  -0.0019352965984552916
# Time:  54 Reward:  -0.0019617366601338707
# Time:  55 Reward:  -0.0019840412443891237
# Time:  56 Reward:  -0.0020027881948141927
# Time:  57 Reward:  -0.0020184975205289886
# Time:  58 Reward:  -0.0020316286389524944
# Time:  59 Reward:  -0.002042583687173943
# Time:  60 Reward:  -0.0020517085614119627
# Time:  61 Reward:  -0.0020592996260558544
# Time:  62 Reward:  -0.002065608189615154
# Time:  63 Reward:  -0.002070845712085651
# Time:  64 Reward:  -0.0020751913198622197
# Time:  65 Reward:  -0.0020787942617920153
# Time:  66 Reward:  -0.0020817796009560247
# Time:  67 Reward:  -0.0020842537235284384
# Time:  68 Reward:  -0.0020863028607575993
# Time:  69 Reward:  -0.0020879995298144806
# Time:  70 Reward:  -0.0020894038545213067
# Time:  71 Reward:  -0.0020905665610686415
# Time:  72 Reward:  -0.002091528627250826
# Time:  73 Reward:  -0.0020923244798910327
# Time:  74 Reward:  -0.002092983381628195
# Time:  75 Reward:  -0.002093527924828235
# Time:  76 Reward:  -0.0020939781239204735
# Time:  77 Reward:  -0.0020943502815114305
# Time:  78 Reward:  -0.002094659347547387
# Time:  79 Reward:  -0.0020949141704408466
# Time:  80 Reward:  -0.00209512550709711
# Time:  81 Reward:  -0.0020952993548060818
# Time:  82 Reward:  -0.00209544346690879
# Time:  83 Reward:  -0.00209556329586419
# Time:  84 Reward:  -0.0020956619760184292
# Time:  85 Reward:  -0.002095743840962112
# Time:  86 Reward:  -0.002095810944811688
# Time:  87 Reward:  -0.002095866421228028
# Time:  88 Reward:  -0.002095912686993243
# Time:  89 Reward:  -0.0020959507230299173
# Time:  90 Reward:  -0.0020959822983839366
# Time:  91 Reward:  -0.0020960082628485406
# Time:  92 Reward:  -0.0020960300292992063
# Time:  93 Reward:  -0.00209604790929633
# Time:  94 Reward:  -0.002096062469989502
# Time:  95 Reward:  -0.002096074435510715
# Time:  96 Reward:  -0.0020960851136144747
# Time:  97 Reward:  -0.002096093658123469
# Time:  98 Reward:  -0.0020961015456757875
# Time:  99 Reward:  -0.0020961070432344697
# Time:  100 Reward:  -0.0020961118992972134
# Time:  101 Reward:  -0.0020961152122948136
# Time:  102 Reward:  -0.002096118181948987
# Time:  103 Reward:  -0.002096121361954765
# Time:  104 Reward:  -0.0020961236269086032
# Time:  105 Reward:  -0.0020961253590940647
# Time:  106 Reward:  -0.0020961272472362737
# Time:  107 Reward:  -0.002096127910252932
# Time:  108 Reward:  -0.0020961291999013745
# Time:  109 Reward:  -0.002096130248429109
# Time:  110 Reward:  -0.0020961309096552993
# Time:  111 Reward:  -0.0020961315596645094
# Time:  112 Reward:  -0.0020961312870531853
# Time:  113 Reward:  -0.0020961312530492415
# Time:  114 Reward:  -0.0020961322817478014
# Time:  115 Reward:  -0.0020961321252120743
# Time:  116 Reward:  -0.0020961321148705164
# Time:  117 Reward:  -0.0020961327135204373
# Time:  118 Reward:  -0.002096132862790906
# Time:  119 Reward:  -0.0020961328864171494
# Time:  120 Reward:  -0.002096133030861435
# Time:  121 Reward:  -0.002096133247644144
# Time:  122 Reward:  -0.002096133584281112
# Time:  123 Reward:  -0.0020961334958880446
# Time:  124 Reward:  -0.002096133495207963
# Time:  125 Reward:  -0.002096133474433813
# Time:  126 Reward:  -0.002096133432787432
# Time:  127 Reward:  -0.002096133368708638
# Time:  128 Reward:  -0.002096133279796914
# Time:  129 Reward:  -0.0020961332166121592
# Time:  130 Reward:  -0.002096132676253121
# Time:  131 Reward:  -0.002096132990771578
# Time:  132 Reward:  -0.0020961331201467437
# Time:  133 Reward:  -0.002096133541790934
# Time:  134 Reward:  -0.0020961335305884335
# Time:  135 Reward:  -0.002096133594926214
# Time:  136 Reward:  -0.0020961336429055426
# Time:  137 Reward:  -0.0020961336763238177
# Time:  138 Reward:  -0.0020961336964329903
# Time:  139 Reward:  -0.0020961337039863207
# Time:  140 Reward:  -0.002096133699266813
# Time:  141 Reward:  -0.00209613368209766
# Time:  142 Reward:  -0.0020961337057263
# Time:  143 Reward:  -0.002096133607319718
# Time:  144 Reward:  -0.002096133004934199
# Time:  145 Reward:  -0.002096133296684358
# Time:  146 Reward:  -0.0020961334955872267
# Time:  147 Reward:  -0.0020961336205195394
# Time:  148 Reward:  -0.0020961337300522344
# Time:  149 Reward:  -0.0020961338282885185
# Time:  150 Reward:  -0.002096133918908498
# Time:  151 Reward:  -0.0020961340053070247
# Time:  152 Reward:  -0.0020961340907206224
# Time:  153 Reward:  -0.002096134232239747
# Time:  154 Reward:  -0.002096134244502268
# Time:  155 Reward:  -0.002096134208803589
# Time:  156 Reward:  -0.0020961339476386408
# Time:  157 Reward:  -0.0020961337641643577
# Time:  158 Reward:  -0.002096133570671576
# Time:  159 Reward:  -0.0020961331847673447
# Time:  160 Reward:  -0.0020961333329049354
# Time:  161 Reward:  -0.0020961334703877505
# Time:  162 Reward:  -0.0020961335329560847
# Time:  163 Reward:  -0.0020961335768444928
# Time:  164 Reward:  -0.0020961336036971006
# Time:  165 Reward:  -0.0020961336145198873
# Time:  166 Reward:  -0.0020961336097182017
# Time:  167 Reward:  -0.0020961335891122633
# Time:  168 Reward:  -0.00209613360582074
# Time:  169 Reward:  -0.0020961334428607425
# Time:  170 Reward:  -0.0020961331625139155
# Time:  171 Reward:  -0.0020961330941637654
# Time:  172 Reward:  -0.002096132585493451
# Time:  173 Reward:  -0.0020961329013553676
# Time:  174 Reward:  -0.002096133055669564
# Time:  175 Reward:  -0.0020961333371421636
# Time:  176 Reward:  -0.0020961333894860814
# Time:  177 Reward:  -0.0020961336892752376
# Time:  178 Reward:  -0.0020961337316859866
# Time:  179 Reward:  -0.0020961338167523
# Time:  180 Reward:  -0.0020961338937701274
# Time:  181 Reward:  -0.0020961339656247855
# Time:  182 Reward:  -0.0020961340350079934
# Time:  183 Reward:  -0.00209613410451893
# Time:  184 Reward:  -0.00209613423065232
# Time:  185 Reward:  -0.0020961342274695934
# Time:  186 Reward:  -0.0020961341756876002
# Time:  187 Reward:  -0.002096133843308186
# Time:  188 Reward:  -0.002096133856210388
# Time:  189 Reward:  -0.002096133320566956
# Time:  190 Reward:  -0.0020961335541105886
# Time:  191 Reward:  -0.00209613356767747
# Time:  192 Reward:  -0.0020961335638651365
# Time:  193 Reward:  -0.00209613354253076
# Time:  194 Reward:  -0.0020961335567657763
# Time:  195 Reward:  -0.002096133389494599
# Time:  196 Reward:  -0.0020961329950563395
# Time:  197 Reward:  -0.0020961331068323646
# Time:  198 Reward:  -0.002096133159066585
# Time:  199 Reward:  -0.0020961332614966486
# Time:  200 Reward:  -0.0020961334718504164
